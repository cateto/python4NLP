# %% [markdown]
# <a href="https://colab.research.google.com/github/cateto/python4NLP/blob/main/20220919/%EC%A3%BC%EC%A0%9C%EB%B6%84%EB%A5%98(model).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import os
abs_path = '/content/drive/MyDrive/DL/(202209) 주제분류 POC'
dir_arr = os.listdir(abs_path)

# %%
dir_arr
# Out:
# ['data_20220117_1.xlsx',
#  'data_201005.xlsx',
#  'data_20210507.xlsx',
#  'pr_report_data_20220117_1.xlsx.html',
#  'pr_report_data_201005.xlsx.html',
#  'pr_report_data_20210507.xlsx.html',
#  'pr_report_data_20220117_1.xlsx.html의 사본']

# %%
latest_data_path = os.path.join(abs_path,dir_arr[0])

latest_data = pd.read_excel(latest_data_path)

# %%
len(latest_data)
# Out:
# 25196

# %%
latest_data = latest_data.drop_duplicates() #중복제거
len(latest_data)
# Out:
# 25196

# %%
latest_data.head()
# Out:
#   No  채널      수집일시 주제 대분류 주제 소분류                             제목  \
# 0  1  언론  20211130     정치     정책            전남 앞바다 함께 계획하고 이용해요
# 1  2  언론  20211130     정치     정책       도송중, 구미 청소년 JTS, 최우수상 쾌거
# 2  3  언론  20211130     정치     정책      새로운대전위원회, 대전의 새로운 미래를 논하다
# 3  4  언론  20211130     정치     정책  울릉중, 청소년 사회 참여 및 정책제안 공모전 우수상
# 4  5  언론  20211130     정치     정책      대구시, 전국 최초 대중교통 마일리지제도 시행
#
#                                                   내용  \
# 0  해양공간관리계획 공청회 열어 주민·전문가 의견 수렴 \n  ▲ 전남도청  [전남/스...
# 1  [구미뉴스]=구미청소년JTS동아리 (도송중 3학년 김민재, 노희수, 류혜림, 박수연...
# 2  정형근 기자 = 대전시는 30일, 대전평생교육진흥원에서 공직자와 새로운대전위원회 위...
# 3  [경상매일신문=조영삼기자]울릉중학교가 경상북도 교육청에서 최근 개최한 ‘청소년 사회...
# 4  대구시 제공     \n[경상매일신문=김영식기자] 대구시가 내년에 새로운 승용차요일...
#
#                                                  URL       사이트명          보드명  \
# 0  http://www.startnews.co.kr/news/articleView.ht...      스타트뉴스  전국  전남  장성군
# 1  http://www.guminews.co.kr/bbs/board.php?bo_tab...       구미뉴스           교육
# 2             https://www.khousenews.com/news/124119  한국부동산종합뉴스         통합뉴스
# 3  http://www.ksmnews.co.kr/default/index_view_pa...       경상매일       뉴스> 뉴스
# 4  http://www.ksmnews.co.kr/default/index_view_pa...       경상매일    뉴스> 정치/행정
#
#                                                 주제단어  작업자  검토결과 오분류 유형  비고
# 0                                    공청회,공청회,공청회,공청회  신효성     1    NaN NaN
# 1                                    사회 정책,정책제안,정책제안  신효성     1    NaN NaN
# 2                 정책위원회,정책방향,정책방향,청년정책,주요시책,자문 역할 수행  신효성     1    NaN NaN
# 3                               정책제안,정책제안,정책박람회,정책제안  신효성     1    NaN NaN
# 4  승용차요일제,승용차요일제,승용차요일제,승용차요일제,승용차요일제,승용차요일제,지역 화...  신효성     1    NaN NaN

# %%
lastest_data = latest_data.dropna(how='all', subset=['제목', '내용'])
len(latest_data)
# Out:
# 25196

# %%
second_data_path = os.path.join(abs_path,dir_arr[1])

second_data = pd.read_excel(second_data_path)

# %%
second_data.head()
# Out:
#                     문서번호        일자  \
# 0   UT000000007798724050  20200903
# 1   QA000000007798712796  20200903
# 2  TW1301533065143967745  20200903
# 3  TW1301534522253565952  20200903
# 4   CF000000007798713901  20200903
#
#                                                   제목  \
# 0   DSLR, 뭐가 좋은거지? / 이벤트픽이 쓰는 카메라! #니콘 #캐논 #행사전문스튜디오
# 1  멜론 mp3 30개 다운 정기결재 신청하고 바로 해지하면 이번 1회만 결재되는거 맞...
# 2                 가습기 쓰는 사람..................잇으면 추천좀
# 3  최신가전 파격 지원! 낸 돈은 전액 그대로 100% 환급. https://t.co/...
# 4                      [질문] 126동(1/2호라인) 9월 입주예정일 문의
#
#                                                   내용 주제 1순위               주제어  \
# 0  안녕하세요, 이벤트픽입니다 :) 이번 영상은 카메라 기종에 대해, 어떤 카메라가 좋...     가전  DSLR,카메라,카메라,카메라
# 1  내공100  \n 멜론 mp3 30개 다운 정기결재 신청하고 바로 해지하면 이번 1...     가전               MP3
# 2                                                NaN     가전               가습기
# 3                                                NaN     가전                가전
# 4  저희가 9월 26일 입주예정이고,\n\n새로 구입한 가구나 가전 등이 9월19일에 ...     가전                가전
#
#                                                   링크  출처  검토결과 오분류 유형
# 0        https://www.youtube.com/watch?v=nVeT8W8rlBA NaN     1    NaN
# 1  https://kin.naver.com/qna/detail.nhn?d1id=1&di... NaN     1    NaN
# 2  https://twitter.com/Bin_527/status/13015330651... NaN     1    NaN
# 3  https://twitter.com/keyanimater/status/1301534... NaN     1    NaN
# 4      https://cafe.naver.com/marineaesiang2020/2426 NaN     1    NaN

# %%
second_data = second_data.drop_duplicates() #중복제거
print(len(second_data))
second_data = second_data.dropna(how='all', subset=['제목', '내용']) #결측치제거
print(len(second_data))
# Out:
# 15664
# 15664

# %%
third_data_path = os.path.join(abs_path,dir_arr[2])

third_data = pd.read_excel(third_data_path)

# %%
third_data.head()
# Out:
#     No                  문서번호        일자                             제목  \
# 0  970  DC000000008462043601  20210303  근데 이거봐 ㅋㅋㅋㅋ 친문에서 유시민 대선 부추기나봐
# 1  971  DC000000008462043611  20210303  유시민이 대선안나가더라도 이재명견제용으로 나올순잇다봄
# 2  972  DC000000008462043564  20210303    대전 세종쪽은 윤석열 나오면 누구 뽑을지 궁금하다
# 3  973  DC000000008462043686  20210303         내가 진보 좋아하면서 졸라 싫어하는 이유
# 4  974  DC000000008462043569  20210303          코로나 끝난 후, 민주당의 변명 예상.
#
#                                                   내용 주제 대분류 주제 소분류      주제어  \
# 0  https://n.news.naver.com/article/025/000308144...     정치     정당      이재명
# 1  친문 새후보한테 지지율 높혀서 전달할 중간다리 이런용도로 이재명한테 안밀리는네임드중...     정치     정당  지지율,이재명
# 2  현재는 싹다 민주당 올킬인데 \n윤석열 나오면 어캐 되려나 \n출신 대통령 vs 그...     정치     정당      민주당
# 3  1.진보지향하는새끼들 보면 거의 대부분\n잘난척이 하늘을 찌름\n인간의 허영심중에 ...     정치     정당   민주당,진보
# 4                       코로나가 끝날 줄 몰랐으니까 독재를 했다.\n이럴듯     정치     정당      민주당
#
#                                               연관어  감성  \
# 0                                      유시민,대선,이재명  중립
# 1                               유시민,네임,대선,지지율,이재명  중립
# 2                            대전,민주당,세종,윤석열,올킬,대통령  중립
# 3  민주당,허영,ㅉㅉ,허영심,불합리,증거,이새끼,좋아하다,충성,지적하다,답답,멍청,생각  부정
# 4                                 독재,변명,민주당,코로나19  부정
#
#                                    링크  작업자  검토결과
# 0  https://www.fmkorea.com/3428613131  은승현     1
# 1  https://www.fmkorea.com/3428620439  은승현     1
# 2  https://www.fmkorea.com/3428581763  은승현     1
# 3  https://www.fmkorea.com/3428650664  은승현     1
# 4  https://www.fmkorea.com/3428584602  은승현     1

# %%
third_data = third_data.drop_duplicates() #중복제거
print(len(third_data))
third_data = third_data.dropna(how='all', subset=['제목', '내용']) #결측치제거
print(len(third_data))
# Out:
# 17090
# 17090

# %%
col_name = ['contents', 'topic_rule', 'topic_human']

# %%
inter_data = pd.DataFrame(columns=col_name)

# %%
inter_data
# Out:
# Empty DataFrame
# Columns: [contents, topic_rule, topic_human]
# Index: []

# %%
lastest_data['contents'] = -1
lastest_data['contents'] = latest_data[['제목','내용']].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# %%
lastest_data['topic_rule'] = -1
lastest_data['topic_rule'] = latest_data['주제 소분류']
lastest_data['topic_human'] = -1

# %%
lastest_data.head()
# Out:
#   No  채널      수집일시 주제 대분류 주제 소분류                             제목  \
# 0  1  언론  20211130     정치     정책            전남 앞바다 함께 계획하고 이용해요
# 1  2  언론  20211130     정치     정책       도송중, 구미 청소년 JTS, 최우수상 쾌거
# 2  3  언론  20211130     정치     정책      새로운대전위원회, 대전의 새로운 미래를 논하다
# 3  4  언론  20211130     정치     정책  울릉중, 청소년 사회 참여 및 정책제안 공모전 우수상
# 4  5  언론  20211130     정치     정책      대구시, 전국 최초 대중교통 마일리지제도 시행
#
#                                                   내용  \
# 0  해양공간관리계획 공청회 열어 주민·전문가 의견 수렴 \n  ▲ 전남도청  [전남/스...
# 1  [구미뉴스]=구미청소년JTS동아리 (도송중 3학년 김민재, 노희수, 류혜림, 박수연...
# 2  정형근 기자 = 대전시는 30일, 대전평생교육진흥원에서 공직자와 새로운대전위원회 위...
# 3  [경상매일신문=조영삼기자]울릉중학교가 경상북도 교육청에서 최근 개최한 ‘청소년 사회...
# 4  대구시 제공     \n[경상매일신문=김영식기자] 대구시가 내년에 새로운 승용차요일...
#
#                                                  URL       사이트명          보드명  \
# 0  http://www.startnews.co.kr/news/articleView.ht...      스타트뉴스  전국  전남  장성군
# 1  http://www.guminews.co.kr/bbs/board.php?bo_tab...       구미뉴스           교육
# 2             https://www.khousenews.com/news/124119  한국부동산종합뉴스         통합뉴스
# 3  http://www.ksmnews.co.kr/default/index_view_pa...       경상매일       뉴스> 뉴스
# 4  http://www.ksmnews.co.kr/default/index_view_pa...       경상매일    뉴스> 정치/행정
#
#                                                 주제단어  작업자  검토결과 오분류 유형  비고  \
# 0                                    공청회,공청회,공청회,공청회  신효성     1    NaN NaN
# 1                                    사회 정책,정책제안,정책제안  신효성     1    NaN NaN
# 2                 정책위원회,정책방향,정책방향,청년정책,주요시책,자문 역할 수행  신효성     1    NaN NaN
# 3                               정책제안,정책제안,정책박람회,정책제안  신효성     1    NaN NaN
# 4  승용차요일제,승용차요일제,승용차요일제,승용차요일제,승용차요일제,승용차요일제,지역 화...  신효성     1    NaN NaN
#
#                                             contents topic_rule  topic_human
# 0  전남 앞바다 함께 계획하고 이용해요 해양공간관리계획 공청회 열어 주민·전문가 의견 ...         정책           -1
# 1  도송중, 구미 청소년 JTS, 최우수상 쾌거 [구미뉴스]=구미청소년JTS동아리 (도...         정책           -1
# 2  새로운대전위원회, 대전의 새로운 미래를 논하다 정형근 기자 = 대전시는 30일, 대...         정책           -1
# 3  울릉중, 청소년 사회 참여 및 정책제안 공모전 우수상 [경상매일신문=조영삼기자]울릉...         정책           -1
# 4  대구시, 전국 최초 대중교통 마일리지제도 시행 대구시 제공     \n[경상매일신문...         정책           -1

# %%
inter_data = inter_data.append(lastest_data[col_name], ignore_index = True)

# %%
inter_data
# Out:
#                                                 contents topic_rule  \
# 0      전남 앞바다 함께 계획하고 이용해요 해양공간관리계획 공청회 열어 주민·전문가 의견 ...         정책
# 1      도송중, 구미 청소년 JTS, 최우수상 쾌거 [구미뉴스]=구미청소년JTS동아리 (도...         정책
# 2      새로운대전위원회, 대전의 새로운 미래를 논하다 정형근 기자 = 대전시는 30일, 대...         정책
# 3      울릉중, 청소년 사회 참여 및 정책제안 공모전 우수상 [경상매일신문=조영삼기자]울릉...         정책
# 4      대구시, 전국 최초 대중교통 마일리지제도 시행 대구시 제공     \n[경상매일신문...         정책
# ...                                                  ...        ...
# 25191  비맥스녹십자 Pow7.kr 비맥스녹십자 Pow7.kr\t\n작성자 카톡EXXE\n\...        바이오
# 25192  센트리가격「카톡EXXE」 센트리가격「카톡EXXE」\t\n작성자 카톡EXXE\n\t\...        바이오
# 25193  레비트라가격 레비트라가격\t\n작성자 카톡EXXE\n\t\n작성일 2021-11-2...        바이오
# 25194  카마그라젤 XXA.KR 카마그라젤 XXA.KR\t\n작성자 카톡EXXE\n\t\n작...        바이오
# 25195  조루봉침 카톡:EXXE 조루봉침 카톡:EXXE\t\n작성자 카톡EXXE\n\t\n작...        바이오
#
#       topic_human
# 0              -1
# 1              -1
# 2              -1
# 3              -1
# 4              -1
# ...           ...
# 25191          -1
# 25192          -1
# 25193          -1
# 25194          -1
# 25195          -1
#
# [25196 rows x 3 columns]

# %%
second_data['contents'] = -1
second_data['contents'] = second_data[['제목','내용']].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# %%
second_data['topic_rule'] = -1
second_data['topic_rule'] = second_data['주제 1순위']
second_data['topic_human'] = -1

# %%
second_data.head()
# Out:
#                     문서번호        일자  \
# 0   UT000000007798724050  20200903
# 1   QA000000007798712796  20200903
# 2  TW1301533065143967745  20200903
# 3  TW1301534522253565952  20200903
# 4   CF000000007798713901  20200903
#
#                                                   제목  \
# 0   DSLR, 뭐가 좋은거지? / 이벤트픽이 쓰는 카메라! #니콘 #캐논 #행사전문스튜디오
# 1  멜론 mp3 30개 다운 정기결재 신청하고 바로 해지하면 이번 1회만 결재되는거 맞...
# 2                 가습기 쓰는 사람..................잇으면 추천좀
# 3  최신가전 파격 지원! 낸 돈은 전액 그대로 100% 환급. https://t.co/...
# 4                      [질문] 126동(1/2호라인) 9월 입주예정일 문의
#
#                                                   내용 주제 1순위               주제어  \
# 0  안녕하세요, 이벤트픽입니다 :) 이번 영상은 카메라 기종에 대해, 어떤 카메라가 좋...     가전  DSLR,카메라,카메라,카메라
# 1  내공100  \n 멜론 mp3 30개 다운 정기결재 신청하고 바로 해지하면 이번 1...     가전               MP3
# 2                                                NaN     가전               가습기
# 3                                                NaN     가전                가전
# 4  저희가 9월 26일 입주예정이고,\n\n새로 구입한 가구나 가전 등이 9월19일에 ...     가전                가전
#
#                                                   링크  출처  검토결과 오분류 유형  \
# 0        https://www.youtube.com/watch?v=nVeT8W8rlBA NaN     1    NaN
# 1  https://kin.naver.com/qna/detail.nhn?d1id=1&di... NaN     1    NaN
# 2  https://twitter.com/Bin_527/status/13015330651... NaN     1    NaN
# 3  https://twitter.com/keyanimater/status/1301534... NaN     1    NaN
# 4      https://cafe.naver.com/marineaesiang2020/2426 NaN     1    NaN
#
#                                             contents topic_rule  topic_human
# 0  DSLR, 뭐가 좋은거지? / 이벤트픽이 쓰는 카메라! #니콘 #캐논 #행사전문스튜...         가전           -1
# 1  멜론 mp3 30개 다운 정기결재 신청하고 바로 해지하면 이번 1회만 결재되는거 맞...         가전           -1
# 2             가습기 쓰는 사람..................잇으면 추천좀 nan         가전           -1
# 3  최신가전 파격 지원! 낸 돈은 전액 그대로 100% 환급. https://t.co/...         가전           -1
# 4  [질문] 126동(1/2호라인) 9월 입주예정일 문의 저희가 9월 26일 입주예정이...         가전           -1

# %%
inter_data = inter_data.append(second_data[col_name], ignore_index = True)

# %%
inter_data
# Out:
#                                                 contents topic_rule  \
# 0      전남 앞바다 함께 계획하고 이용해요 해양공간관리계획 공청회 열어 주민·전문가 의견 ...         정책
# 1      도송중, 구미 청소년 JTS, 최우수상 쾌거 [구미뉴스]=구미청소년JTS동아리 (도...         정책
# 2      새로운대전위원회, 대전의 새로운 미래를 논하다 정형근 기자 = 대전시는 30일, 대...         정책
# 3      울릉중, 청소년 사회 참여 및 정책제안 공모전 우수상 [경상매일신문=조영삼기자]울릉...         정책
# 4      대구시, 전국 최초 대중교통 마일리지제도 시행 대구시 제공     \n[경상매일신문...         정책
# ...                                                  ...        ...
# 40855  홈캉스를 더 빛나게 하는 인천 아파트 유리창 청소☆영종힐스테이트아파트☆ 안녕하세요\...       환경오염
# 40856  @_listk 불끄고 티비보면 눈 나빠져여~!! (황사때 세차하면 기스나여 톤으로)...       환경오염
# 40857                황사빼기재밋어 https://t.co/qDDj2IWLXI nan       환경오염
# 40858  생각만 해도 행복하다.. 역시 난 가을 겨울이 좋은 fw 인간이야 봄엔 황사 때문에...       환경오염
# 40859  식약처 인증 마스크/ 리릿 KF-AD 비말 마스크/ 리릿 KF-94마스크 추천!! ...       환경오염
#
#       topic_human
# 0              -1
# 1              -1
# 2              -1
# 3              -1
# 4              -1
# ...           ...
# 40855          -1
# 40856          -1
# 40857          -1
# 40858          -1
# 40859          -1
#
# [40860 rows x 3 columns]

# %%
third_data['contents'] = -1
third_data['contents'] = third_data[['제목','내용']].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# %%
third_data['topic_rule'] = -1
third_data['topic_rule'] = third_data['주제 소분류']
third_data['topic_human'] = -1

# %%
third_data.head()
# Out:
#     No                  문서번호        일자                             제목  \
# 0  970  DC000000008462043601  20210303  근데 이거봐 ㅋㅋㅋㅋ 친문에서 유시민 대선 부추기나봐
# 1  971  DC000000008462043611  20210303  유시민이 대선안나가더라도 이재명견제용으로 나올순잇다봄
# 2  972  DC000000008462043564  20210303    대전 세종쪽은 윤석열 나오면 누구 뽑을지 궁금하다
# 3  973  DC000000008462043686  20210303         내가 진보 좋아하면서 졸라 싫어하는 이유
# 4  974  DC000000008462043569  20210303          코로나 끝난 후, 민주당의 변명 예상.
#
#                                                   내용 주제 대분류 주제 소분류      주제어  \
# 0  https://n.news.naver.com/article/025/000308144...     정치     정당      이재명
# 1  친문 새후보한테 지지율 높혀서 전달할 중간다리 이런용도로 이재명한테 안밀리는네임드중...     정치     정당  지지율,이재명
# 2  현재는 싹다 민주당 올킬인데 \n윤석열 나오면 어캐 되려나 \n출신 대통령 vs 그...     정치     정당      민주당
# 3  1.진보지향하는새끼들 보면 거의 대부분\n잘난척이 하늘을 찌름\n인간의 허영심중에 ...     정치     정당   민주당,진보
# 4                       코로나가 끝날 줄 몰랐으니까 독재를 했다.\n이럴듯     정치     정당      민주당
#
#                                               연관어  감성  \
# 0                                      유시민,대선,이재명  중립
# 1                               유시민,네임,대선,지지율,이재명  중립
# 2                            대전,민주당,세종,윤석열,올킬,대통령  중립
# 3  민주당,허영,ㅉㅉ,허영심,불합리,증거,이새끼,좋아하다,충성,지적하다,답답,멍청,생각  부정
# 4                                 독재,변명,민주당,코로나19  부정
#
#                                    링크  작업자  검토결과  \
# 0  https://www.fmkorea.com/3428613131  은승현     1
# 1  https://www.fmkorea.com/3428620439  은승현     1
# 2  https://www.fmkorea.com/3428581763  은승현     1
# 3  https://www.fmkorea.com/3428650664  은승현     1
# 4  https://www.fmkorea.com/3428584602  은승현     1
#
#                                             contents topic_rule  topic_human
# 0  근데 이거봐 ㅋㅋㅋㅋ 친문에서 유시민 대선 부추기나봐 https://n.news.n...         정당           -1
# 1  유시민이 대선안나가더라도 이재명견제용으로 나올순잇다봄 친문 새후보한테 지지율 높혀서...         정당           -1
# 2  대전 세종쪽은 윤석열 나오면 누구 뽑을지 궁금하다 현재는 싹다 민주당 올킬인데 \n...         정당           -1
# 3  내가 진보 좋아하면서 졸라 싫어하는 이유 1.진보지향하는새끼들 보면 거의 대부분\n...         정당           -1
# 4  코로나 끝난 후, 민주당의 변명 예상. 코로나가 끝날 줄 몰랐으니까 독재를 했다.\...         정당           -1

# %%
inter_data = inter_data.append(third_data[col_name], ignore_index = True)

# %%
inter_data
# Out:
#                                                 contents topic_rule  \
# 0      전남 앞바다 함께 계획하고 이용해요 해양공간관리계획 공청회 열어 주민·전문가 의견 ...         정책
# 1      도송중, 구미 청소년 JTS, 최우수상 쾌거 [구미뉴스]=구미청소년JTS동아리 (도...         정책
# 2      새로운대전위원회, 대전의 새로운 미래를 논하다 정형근 기자 = 대전시는 30일, 대...         정책
# 3      울릉중, 청소년 사회 참여 및 정책제안 공모전 우수상 [경상매일신문=조영삼기자]울릉...         정책
# 4      대구시, 전국 최초 대중교통 마일리지제도 시행 대구시 제공     \n[경상매일신문...         정책
# ...                                                  ...        ...
# 57945  전북 뿌리·농기계 기술 고도화 지원 본격 가동 □ 전라북도가 주력산업의 근간이 되는...      금융/금리
# 57946  주상하이총영사, 주재국 언론(제일재경(第一財經)) 인터뷰 □ 매체 및 기고 일시 :...      금융/금리
# 57947  2021년 1월 수출입 무역 동향 (관할지역 5개현) ※ 주히로시마총영사관 관할지역...      금융/금리
# 57948  4차 재난지원금 집합제한업종에 매출비교는 너무 잔인하고 불공정합니다. 오늘 기획재정...      금융/금리
# 57949  공시송달(2021-4호) 납부의무자들에게 송달할 위 서류를 인천지방검찰청 부천지청에...      금융/금리
#
#       topic_human
# 0              -1
# 1              -1
# 2              -1
# 3              -1
# 4              -1
# ...           ...
# 57945          -1
# 57946          -1
# 57947          -1
# 57948          -1
# 57949          -1
#
# [57950 rows x 3 columns]

# %%
inter_data.loc[inter_data['topic_rule'] == '공연,전시','topic_rule'] = '공연/전시'

# %%
inter_data.loc[inter_data['topic_rule'] == '금융 / 금리','topic_rule'] = '금융/금리'
inter_data.loc[inter_data['topic_rule'] == '금융,금리','topic_rule'] = '금융/금리'

# %%
inter_data.loc[inter_data['topic_rule'] == '스포츠 일반','topic_rule'] = '스포츠일반'

# %%
inter_data.loc[inter_data['topic_rule'] == '여행,레저','topic_rule'] = '여행/레저'

# %%
inter_data.loc[inter_data['topic_rule'] == '유통,쇼핑,물류','topic_rule'] = '유통/쇼핑/물류'

# %%
inter_data.loc[inter_data['topic_rule'] == '취미,반려동물,라이프스타일','topic_rule'] = '취미/반려동물/라이프스타일'
inter_data.loc[inter_data['topic_rule'] == '취미/반려동물/라이프 스타일','topic_rule'] = '취미/반려동물/라이프스타일'

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
encoder.fit(inter_data['topic_rule'])
inter_data['topic_human'] = encoder.transform(inter_data['topic_rule'])

# %%
# print labels
for i, label in enumerate(encoder.classes_):
    print(i, '->', label)
# Out:
# 0 -> 가전
# 1 -> 건설
# 2 -> 게임
# 3 -> 골프
# 4 -> 공연/전시
# 5 -> 교육
# 6 -> 국방안보
# 7 -> 금융/금리
# 8 -> 농구
# 9 -> 다문화
# 10 -> 도서
# 11 -> 레져산업
# 12 -> 모바일
# 13 -> 바이오
# 14 -> 반도체
# 15 -> 방송
# 16 -> 배구
# 17 -> 법조
# 18 -> 보건복지
# 19 -> 부동산
# 20 -> 사건사고
# 21 -> 석유
# 22 -> 스포츠일반
# 23 -> 식품
# 24 -> 야구
# 25 -> 에너지
# 26 -> 여행/레저
# 27 -> 연예일반
# 28 -> 영화
# 29 -> 외교
# 30 -> 유통/쇼핑/물류
# 31 -> 음식
# 32 -> 음악
# 33 -> 의료
# 34 -> 인터넷
# 35 -> 자동차
# 36 -> 재해
# 37 -> 전자
# 38 -> 정당
# 39 -> 정부
# 40 -> 정책
# 41 -> 제철
# 42 -> 종교
# 43 -> 증권
# 44 -> 지자체
# 45 -> 축구
# 46 -> 취미/반려동물/라이프스타일
# 47 -> 친환경
# 48 -> 컴퓨터
# 49 -> 통신
# 50 -> 패션
# 51 -> 화학
# 52 -> 환경오염

# %%
inter_data
# Out:
#                                                 contents topic_rule  \
# 0      전남 앞바다 함께 계획하고 이용해요 해양공간관리계획 공청회 열어 주민·전문가 의견 ...         정책
# 1      도송중, 구미 청소년 JTS, 최우수상 쾌거 [구미뉴스]=구미청소년JTS동아리 (도...         정책
# 2      새로운대전위원회, 대전의 새로운 미래를 논하다 정형근 기자 = 대전시는 30일, 대...         정책
# 3      울릉중, 청소년 사회 참여 및 정책제안 공모전 우수상 [경상매일신문=조영삼기자]울릉...         정책
# 4      대구시, 전국 최초 대중교통 마일리지제도 시행 대구시 제공     \n[경상매일신문...         정책
# ...                                                  ...        ...
# 57945  전북 뿌리·농기계 기술 고도화 지원 본격 가동 □ 전라북도가 주력산업의 근간이 되는...      금융/금리
# 57946  주상하이총영사, 주재국 언론(제일재경(第一財經)) 인터뷰 □ 매체 및 기고 일시 :...      금융/금리
# 57947  2021년 1월 수출입 무역 동향 (관할지역 5개현) ※ 주히로시마총영사관 관할지역...      금융/금리
# 57948  4차 재난지원금 집합제한업종에 매출비교는 너무 잔인하고 불공정합니다. 오늘 기획재정...      금융/금리
# 57949  공시송달(2021-4호) 납부의무자들에게 송달할 위 서류를 인천지방검찰청 부천지청에...      금융/금리
#
#        topic_human
# 0               40
# 1               40
# 2               40
# 3               40
# 4               40
# ...            ...
# 57945            7
# 57946            7
# 57947            7
# 57948            7
# 57949            7
#
# [57950 rows x 3 columns]

# %%
train, test = train_test_split(inter_data, test_size=0.2, random_state=42)

# %%
train
# Out:
#                                                 contents topic_rule  \
# 33815  김정은이 반역자로 몰던 ‘강화도 수영 월북자’를 용서한 이유 김씨가 탈출로로 이용한...         외교
# 13293  “언제까지 이렇게 뚱뚱한 지갑을 들고 다녀야 하지?”수많은 직원들의 고민 끝에 탄생...      금융/금리
# 13744  유진 역시 남다른 손재주와 파워를 가진 만능캐였는데요.#해치지않아 ‘해치지 않아’ ...         방송
# 10644  계약 인증합니다! ​\n\n​\n\n​\n\n​\n\n제네시스 GV70클럽 [순회원...         석유
# 46248  '프로 다이어터' 박세리, 낮부터 삼겹살 먹방 "고기는 살 안찜" 사진=박세리 인스...         골프
# ...                                                  ...        ...
# 54343  실전매매 두올 한빛소프트 한농화성 에스퓨얼셀 시초가매매 투매매매! 한숨 돌린 시장~...         화학
# 38158  @eunnybae @Ve7hF2yaXGWijwD 모르겠지만 완전 고점이 아니면 진짜...         증권
# 860    9급 지방직 일반행정공무원 2022년에 지원하고 싶은데 2022년되면 나이가 만17...         정부
# 15795  2021.11.30. 가꿈 "나들이" < 한지연과 함께하는 THE가꿈 > 멘토인 대...      여행/레저
# 56422  제네릭 판매 방해한 대웅제약에 과징금 23억·검찰고발 부당한 특허침해소송에 대한 공...        바이오
#
#        topic_human
# 33815           29
# 13293            7
# 13744           15
# 10644           21
# 46248            3
# ...            ...
# 54343           51
# 38158           43
# 860             39
# 15795           26
# 56422           13
#
# [46360 rows x 3 columns]

# %%
test
# Out:
#                                                 contents topic_rule  \
# 13378  한국은행 신권 교환 관련. 내년부터는 신권을 한국은행 신권 교환 관련. 내년부터는 ...      금융/금리
# 45083  고양의 딸 홍지윤을 응원해 주세요 안녕하세요._x000D_\n우리 고양시의 딸, 홍...       연예일반
# 18528  담주에 할 거 추천 좀 담주 화욜까지 약속 있는데 성적표 금욜에 나오니까 수목 할거...         교육
# 27395  변종공매도가 기승인가보네 https://www1.president.go.kr/pet...      금융/금리
# 14165  ‏  ♥︎ - ‏‎مُوضح اعلاه  -  : - ‏‎‏#TWICE #ONCE ...       연예일반
# ...                                                  ...        ...
# 4911                           직관가서단점...김연경경기생방못봄... nan         배구
# 49352  코스피 2560선까지 떨어진다?? (국내 증시 전망)\n -미국 금리 오르면 외국이...         증권
# 36995  세관땜에 또 일주일 참아야하네 ㅅㅂ 합산과세땜에 한주 늦게 보낸건데 \n\n또 늦어...         정부
# 16261  뇌전증 환자 진로 안녕하세요 저는 뇌전증을 앓고 있는 중학교 3학년 여학생인데요\n...         의료
# 33090  오늘만큼은세상에서우리마키가젤행복해야해 #ForeverWithMarkTuanDay\n...       연예일반
#
#        topic_human
# 13378            7
# 45083           27
# 18528            5
# 27395            7
# 14165           27
# ...            ...
# 4911            16
# 49352           43
# 36995           39
# 16261           33
# 33090           27
#
# [11590 rows x 3 columns]

# %%
train.to_csv(os.path.join(abs_path, 'lucy_topic_train_v1.0.csv'), index=False, encoding="utf-8-sig")

# %%
test.to_csv(os.path.join(abs_path, 'lucy_topic_test_v1.0.csv'), index=False, encoding="utf-8-sig")

# %%
# !pip install git+https://github.com/SKT-AI/KoBART#egg=kobart
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting kobart
#   Cloning https://github.com/SKT-AI/KoBART to /tmp/pip-install-x1nq_q5p/kobart_1276500f4d5842a89d445dfc4692c09c
#   Running command git clone -q https://github.com/SKT-AI/KoBART /tmp/pip-install-x1nq_q5p/kobart_1276500f4d5842a89d445dfc4692c09c
# Collecting boto3
#   Downloading boto3-1.24.76-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 4.8 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from kobart) (1.3.5)
# Collecting pytorch-lightning==1.2.1
#   Downloading pytorch_lightning-1.2.1-py3-none-any.whl (814 kB)
#      |████████████████████████████████| 814 kB 36.6 MB/s
# Collecting torch==1.7.1
#   Downloading torch-1.7.1-cp37-cp37m-manylinux1_x86_64.whl (776.8 MB)
#      |████████████████████████████████| 776.8 MB 18 kB/s
# Collecting transformers==4.3.3
#   Downloading transformers-4.3.3-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 54.6 MB/s
# Collecting future>=0.17.1
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 62.4 MB/s
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.2.1->kobart) (4.64.1)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.2.1->kobart) (2.8.0)
# Requirement already satisfied: PyYAML!=5.4.*,>=5.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.2.1->kobart) (6.0)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.2.1->kobart) (1.21.6)
# Requirement already satisfied: fsspec[http]>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.2.1->kobart) (2022.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.7.1->kobart) (4.1.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->kobart) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->kobart) (4.12.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 65.0 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->kobart) (2.23.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 54.3 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->kobart) (2022.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.3.3->kobart) (3.8.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.7/dist-packages (from fsspec[http]>=0.8.1->pytorch-lightning==1.2.1->kobart) (3.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.8.1->pytorch-lightning==1.2.1->kobart) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.8.1->pytorch-lightning==1.2.1->kobart) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.8.1->pytorch-lightning==1.2.1->kobart) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.8.1->pytorch-lightning==1.2.1->kobart) (1.8.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.8.1->pytorch-lightning==1.2.1->kobart) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.8.1->pytorch-lightning==1.2.1->kobart) (2.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.8.1->pytorch-lightning==1.2.1->kobart) (1.2.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.8.1->pytorch-lightning==1.2.1->kobart) (0.13.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.2.1->kobart) (3.17.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.2.1->kobart) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.2.1->kobart) (0.4.6)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.2.1->kobart) (1.48.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.2.1->kobart) (1.2.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.2.1->kobart) (57.4.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.2.1->kobart) (0.37.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.2.1->kobart) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.2.1->kobart) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.2.1->kobart) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.2.1->kobart) (3.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.2.1->kobart) (4.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.2.1->kobart) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.2.1->kobart) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.2.1->kobart) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.2.1->kobart) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.3.3->kobart) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.2.1->kobart) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3->kobart) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3->kobart) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3->kobart) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.3.3->kobart) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.2.1->kobart) (3.2.0)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 10.5 MB/s
# Collecting botocore<1.28.0,>=1.27.76
#   Downloading botocore-1.27.76-py3-none-any.whl (9.1 MB)
#      |████████████████████████████████| 9.1 MB 50.7 MB/s
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.28.0,>=1.27.76->boto3->kobart) (2.8.2)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 69.3 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==4.3.3->kobart) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->kobart) (2022.2.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.3.3->kobart) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.3.3->kobart) (1.1.0)
# Building wheels for collected packages: kobart, future, sacremoses
#   Building wheel for kobart (setup.py) ... done
#   Created wheel for kobart: filename=kobart-0.5.1-py3-none-any.whl size=9583 sha256=12dc671954a5f23317361e604998e0043a94cdd3fd0583f92cc63e30d7aecb77
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mqa55hr8/wheels/6e/55/c4/bd4fede223bc304089ac8da2a2099a69db3fcd4b0e853383f5
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=009626c56a4bcc54111b1d2e2f01e7237c75da775e62bc3b106cef37b7ac98e1
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=441c344f34d7a1f46157204918026d032ca81a46cd3f1da68a61401a893ff397
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built kobart future sacremoses
# Installing collected packages: urllib3, jmespath, botocore, torch, tokenizers, sacremoses, s3transfer, future, transformers, pytorch-lightning, boto3, kobart
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.13.1+cu113 requires torch==1.12.1, but you have torch 1.7.1 which is incompatible.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.7.1 which is incompatible.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 1.7.1 which is incompatible.
# Successfully installed boto3-1.24.76 botocore-1.27.76 future-0.18.2 jmespath-1.0.1 kobart-0.5.1 pytorch-lightning-1.2.1 s3transfer-0.6.0 sacremoses-0.0.53 tokenizers-0.10.3 torch-1.7.1 transformers-4.3.3 urllib3-1.25.11

# %%
# !pip install torchtext==0.8.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchtext==0.8.1
#   Downloading torchtext-0.8.1-cp37-cp37m-manylinux1_x86_64.whl (7.0 MB)
#      |████████████████████████████████| 7.0 MB 4.7 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchtext==0.8.1) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext==0.8.1) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext==0.8.1) (4.64.1)
# Requirement already satisfied: torch==1.7.1 in /usr/local/lib/python3.7/dist-packages (from torchtext==0.8.1) (1.7.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.7.1->torchtext==0.8.1) (4.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.8.1) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.8.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.8.1) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.8.1) (1.25.11)
# Installing collected packages: torchtext
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.13.1
#     Uninstalling torchtext-0.13.1:
#       Successfully uninstalled torchtext-0.13.1
# Successfully installed torchtext-0.8.1

# %%
# !python /content/drive/MyDrive/DL/topic_class_POC/source/lucy.py --gpus 1 --max_epochs 3 --default_root_dir .cache --gradient_clip_val 1.0
# Out:
# INFO:root:Namespace(accelerator=None, accumulate_grad_batches=1, amp_backend='native', amp_level='O2', auto_lr_find=False, auto_scale_batch_size=False, auto_select_gpus=False, automatic_optimization=None, batch_size=6, benchmark=False, cachedir='/content/.cache', check_val_every_n_epoch=1, checkpoint_callback=True, default_root_dir='.cache', deterministic=False, distributed_backend=None, enable_pl_optimizer=None, fast_dev_run=False, flush_logs_every_n_steps=100, gpus=1, gradient_clip_val=1.0, limit_predict_batches=1.0, limit_test_batches=1.0, limit_train_batches=1.0, limit_val_batches=1.0, log_every_n_steps=50, log_gpu_memory=None, logger=True, lr=5e-05, max_epochs=3, max_seq_len=512, max_steps=None, min_epochs=None, min_steps=None, move_metrics_to_cpu=False, multiple_trainloader_mode='max_size_cycle', num_nodes=1, num_processes=1, num_sanity_val_steps=2, overfit_batches=0.0, plugins=None, precision=32, prepare_data_per_node=True, process_position=0, profiler=None, progress_bar_refresh_rate=None, reload_dataloaders_every_epoch=False, replace_sampler_ddp=True, resume_from_checkpoint=None, stochastic_weight_avg=False, subtask='lucy', sync_batchnorm=False, terminate_on_nan=False, tpu_cores=<function _gpus_arg_default at 0x7f0452d405f0>, track_grad_norm=-1, truncated_bptt_steps=None, val_check_interval=1.0, warmup_ratio=0.1, weights_save_path=None, weights_summary='top')
# using cached model. /content/.cache/kobart_base_cased_ff4bda5738.zip
# Some weights of BartForSequenceClassification were not initialized from the model checkpoint at /content/.cache/kobart_from_pretrained and are newly initialized: ['classification_head.dense.bias', 'classification_head.dense.weight', 'classification_head.out_proj.bias', 'classification_head.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# GPU available: True, used: True
# INFO:lightning:GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# INFO:lightning:TPU available: None, using: 0 TPU cores
# using cached model. /content/.cache/kobart_base_tokenizer_cased_cf74400bce.zip
# using cached model. /content/.cache/kobart_base_tokenizer_cased_cf74400bce.zip
# INFO:pytorch_lightning.accelerators.gpu:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:root:number of workers 1, data length 46360
# INFO:root:num_train_steps : 23180
# INFO:root:num_warmup_steps : 2318
#
#   | Name       | Type                          | Params
# -------------------------------------------------------------
# 0 | model      | BartForSequenceClassification | 124 M
# 1 | metric_acc | Accuracy                      | 0
# -------------------------------------------------------------
# 124 M     Trainable params
# 0         Non-trainable params
# 124 M     Total params
# 497.965   Total estimated model params size (MB)
# INFO:lightning:
#   | Name       | Type                          | Params
# -------------------------------------------------------------
# 0 | model      | BartForSequenceClassification | 124 M
# 1 | metric_acc | Accuracy                      | 0
# -------------------------------------------------------------
# 124 M     Trainable params
# 0         Non-trainable params
# 124 M     Total params
# 497.965   Total estimated model params size (MB)
# Epoch 0:  80% 7740/9659 [1:38:23<24:23,  1.31it/s, loss=1.22, v_num=8, val_acc=0.000, train_loss=1.780]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/1932 [00:00<?, ?it/s]
# Epoch 0:  80% 7760/9659 [1:38:28<24:05,  1.31it/s, loss=1.22, v_num=8, val_acc=0.000, train_loss=1.780]
# Epoch 0: